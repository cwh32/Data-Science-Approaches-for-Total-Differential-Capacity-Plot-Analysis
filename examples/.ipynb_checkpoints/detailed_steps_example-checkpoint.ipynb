# %% [markdown]
# # Detailed Steps Example
#
# #### This notebook demonstrates data cleaning, peak fitting and descriptors generation step by step, serving as a detailed example of the `process_data_example.ipynb`.

# %% [markdown]
# ### Packages and Needed Files Preparation

# %% [markdown]
# #### First, we import the packates we need:

# %%
import sys
sys.path.append("../data-science-appraoches-for-tdcp-analysis")
import chachifuncs as ccf
import databasefuncs as dbfs
import databasewrappers_forjupyter as dbfj
import itertools
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import peakutils
import scipy
import sqlite3 as sql

# %matplotlib inline

# %% [markdown]
# #### And we use an example database and raw data to demonstrate.

# %%
database = 'MyExampleDatabase.db'
path = 'CS2_33_10_04_10.xlsx'
datatype = 'CALCE'
username = 'Mary Poppins'

#the below is to get the variable filename
filename = path
while '/' in filename:
    filename = filename.split('/', maxsplit = 1)[1]
print(filename)
# Out:
# CS2_33_10_04_10.xlsx

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Let's  first define some variable names for later uses:

# %%
# If you are interested in plotting something other than 
# the file that was just processed, simply change the base_filename
# variable to the file name in the database you wish to plot. 
base_filename = filename.split(".")[0] 
raw_filename = base_filename + "Raw"
model_filename = base_filename + "-ModPoints"
descriptors_filename = base_filename + "ModParams-descriptors"
clean_filename = base_filename + "CleanSet"
print('base_filename =',base_filename)
print('raw_filename =',raw_filename)
print('model_filename =',model_filename)
print('descriptors_filename =',descriptors_filename)
print('clean_filename =',clean_filename)
# Out:
# base_filename = CS2_33_10_04_10
# raw_filename = CS2_33_10_04_10Raw
# model_filename = CS2_33_10_04_10-ModPoints
# descriptors_filename = CS2_33_10_04_10ModParams-descriptors
# clean_filename = CS2_33_10_04_10CleanSet

# %% [markdown]
# #### Then, we take a look at the cycle 1 of raw data

# %%
raw_df = dbfs.get_file_from_database(raw_filename, database)

fig1 = plt.figure(figsize = (7,8), facecolor = 'w', edgecolor= 'k')
# create the color map based off of the max value in the cycle index column
colors = matplotlib.cm.Greys(np.linspace(0.3, 1, int(max(raw_df['Cycle_Index']))))

cycle_to_plot = 1
# plot cycle 1, this number can be changed to any cycle

for name, group in raw_df.groupby(['Cycle_Index']):
    if name == cycle_to_plot:
        plt.plot(group['Voltage(V)'], group['dQ/dV'], c = 'black', linewidth = 2, label = 'Raw Cycle Data') 
#for name, group in mod_df.groupby(['Cycle_Index']): 
    #if name == cycle_to_plot:
        #plt.plot(group['Voltage(V)'], group['Model'], c = 'red', linewidth = 2, label = 'Model', linestyle = '--')

#plt.legend()
#leg = plt.legend(loc = 'upper right', fontsize = 14)
plt.ylabel('dQ/dV (Ah/V)', fontsize =20)
plt.xlabel('Voltage(V)', fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.tick_params(size = 10, width = 1)
plt.title('Raw Data', fontsize = 24)

# plt.xlim(0, 4)
plt.ylim(-7,7)

# Uncomment the following line if you would like to save the plot. 
# plt.savefig(fname = 'MyExampleCycle.png', bbox_inches='tight', dpi = 600)
# Out:
# (-7, 7)

# %% [markdown]
# #### Excute fuction `drop_0_dv` to drop rows where dV=0 (or about 0) in a dataframe that has already had dv calculated, then recalculates dV and calculates dQ/dV.

# %%
thresh1 = 4.17
thresh2 = 4.25
datatype = 'CALCE'

cleaned_df = ccf.drop_0_dv(raw_df, thresh1, thresh2, datatype)

fig2 = plt.figure(figsize = (7,8), facecolor = 'w', edgecolor= 'k')
# create the color map based off of the max value in the cycle index column
colors = matplotlib.cm.Greys(np.linspace(0.3, 1, int(max(clean_df['Cycle_Index']))))

cycle_to_plot = 1
# plot cycle 1, this number can be changed to any cycle

for name, group in cleaned_df.groupby(['Cycle_Index']):
    if name == cycle_to_plot:
        plt.plot(group['Voltage(V)'], group['dQ/dV'], c = 'green', linewidth = 2, label = 'Cleaned Cycle Data') 
#for name, group in mod_df.groupby(['Cycle_Index']): 
    #if name == cycle_to_plot:
        #plt.plot(group['Voltage(V)'], group['Model'], c = 'red', linewidth = 2, label = 'Model', linestyle = '--')

#plt.legend()
#leg = plt.legend(loc = 'upper right', fontsize = 14)
plt.ylabel('dQ/dV (Ah/V)', fontsize =20)
plt.xlabel('Voltage(V)', fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.tick_params(size = 10, width = 1)
plt.title('Cleaned Data', fontsize = 24)

# plt.xlim(0, 4)
plt.ylim(-7,7)

# Uncomment the following line if you would like to save the plot. 
# plt.savefig(fname = 'MyExampleCycle.png', bbox_inches='tight', dpi = 600)
# Out:
# (-7, 7)

# %%
datatype = 'CALCE'
sep_cleaned_df = ccf.sep_char_dis(cleaned_df, datatype)

windowlength = 21
polyorder = 3
smoothed_df = ccf.my_savgolay(sep_cleaned_df, windowlength, polyorder) 

fig3 = plt.figure(figsize = (7,8), facecolor = 'w', edgecolor= 'k')
# create the color map based off of the max value in the cycle index column
colors = matplotlib.cm.Greys(np.linspace(0.3, 1, int(max(smoothed_df['Cycle_Index']))))

cycle_to_plot = 1
# plot cycle 1, this number can be changed to any cycle

for name, group in smoothed_df.groupby(['Cycle_Index']):
    if name == cycle_to_plot:
        plt.plot(group['Voltage(V)'], group['dQ/dV'], c = 'green', linewidth = 2, label = 'Smoothed Cycle Data') 
#for name, group in mod_df.groupby(['Cycle_Index']): 
    #if name == cycle_to_plot:
        #plt.plot(group['Voltage(V)'], group['Model'], c = 'red', linewidth = 2, label = 'Model', linestyle = '--')

#plt.legend()
#leg = plt.legend(loc = 'upper right', fontsize = 14)
plt.ylabel('dQ/dV (Ah/V)', fontsize =20)
plt.xlabel('Voltage(V)', fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.tick_params(size = 10, width = 1)
plt.title('Smoothed Data', fontsize = 24)

# plt.xlim(0, 4)
plt.ylim(-7,7)

# Uncomment the following line if you would like to save the plot. 
# plt.savefig(fname = 'MyExampleCycle.png', bbox_inches='tight', dpi = 600)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-18f04d45ffed> in <module>
#       4 windowlength = 21
#       5 polyorder = 3
# ----> 6 smoothed_df = ccf.my_savgolay(sep_cleaned_df, windowlength, polyorder)
#       7
#       8 fig3 = plt.figure(figsize = (7,8), facecolor = 'w', edgecolor= 'k')
#
# C:\Family\David\UW_ChemE\Holmberg_s Group\My Project\Data-Science-Approaches-for-Total-Differential-Capacity-Plot-Analysis\data-science-appraoches-for-tdcp-analysis\chachifuncs.py in my_savgolay(dataframe, windowlength, polyorder)
#     311     assert polyorder < windowlength
#     312     # necessary to run the savgol_filter function as well.
# --> 313     unfilt = pd.concat([dataframe['dQ/dV']])
#     314     unfiltar = unfilt.values
#     315     # converts into an array
#
# TypeError: tuple indices must be integers or slices, not str

# %%
datatype = 'CALCE'
sep_cleaned_df = ccf.sep_char_dis(cleaned_df, datatype)
sep_cleaned_df
# Out:
# (      index  ACI_Phase_Angle(Deg)  AC_Impedance(Ohm)  Charge_Capacity(Ah)  \
#  0      5253                     0                  0            12.837054
#  1      5254                     0                  0            12.837054
#  2      5255                     0                  0            12.837054
#  3      5256                     0                  0            12.837054
#  4      5257                     0                  0            12.837054
#  ...     ...                   ...                ...                  ...
#  4786  10293                     0                  0            24.624331
#  4787  10294                     0                  0            24.624331
#  4788  10295                     0                  0            24.624331
#  4789  10296                     0                  0            24.624331
#  4790  10297                     0                  0            24.624331
#
#        Charge_Energy(Wh)  Charge_dQ  Current(A)  Cycle_Index  Data_Point  \
#  0             50.997574        NaN   -0.550173           12        5486
#  1             50.997574        NaN   -0.550173           12        5487
#  2             50.997574        NaN   -0.550173           12        5488
#  3             50.997574        NaN   -0.550173           12        5489
#  4             50.997574        NaN   -0.550353           12        5490
#  ...                 ...        ...         ...          ...         ...
#  4786          97.876133        NaN   -0.549993           23       10755
#  4787          97.876133        NaN   -0.550173           23       10756
#  4788          97.876133        NaN   -0.550173           23       10757
#  4789          97.876133        NaN   -0.550173           23       10758
#  4790          97.876133        NaN   -0.550173           23       10759
#
#                  Date_Time  ...  Is_FC_Data  Step_Index  Step_Time(s)  \
#  0     2010-09-29 16:34:26  ...           0           7     30.015232
#  1     2010-09-29 16:34:56  ...           0           7     60.030490
#  2     2010-09-29 16:35:26  ...           0           7     90.045766
#  3     2010-09-29 16:35:56  ...           0           7    120.061027
#  4     2010-09-29 16:36:26  ...           0           7    150.076329
#  ...                   ...  ...         ...         ...           ...
#  4786  2010-10-01 17:14:23  ...           0           7    750.381752
#  4787  2010-10-01 17:14:53  ...           0           7    780.397083
#  4788  2010-10-01 17:15:23  ...           0           7    810.412421
#  4789  2010-10-01 17:15:53  ...           0           7    840.412830
#  4790  2010-10-01 17:16:23  ...           0           7    870.427138
#
#         Test_Time(s)  Voltage(V)     dQ/dV        dV  dV/dt(V/s)  datatype  \
#  0     181314.116206    4.101412 -0.051206 -0.089581   -0.000454     CALCE
#  1     181344.131464    4.087805 -0.337105 -0.013608   -0.000324     CALCE
#  2     181374.146740    4.078571 -0.496794 -0.009233   -0.000194     CALCE
#  3     181404.162001    4.071444 -0.643561 -0.007128   -0.000162     CALCE
#  4     181434.177302    4.065450 -0.765368 -0.005993   -0.000162     CALCE
#  ...             ...         ...       ...       ...         ...       ...
#  4786  356498.076170    3.983482 -1.231104 -0.003726   -0.000065     CALCE
#  4787  356528.091502    3.979756 -1.231179 -0.003726   -0.000065     CALCE
#  4788  356558.106839    3.976031 -1.231148 -0.003726   -0.000097     CALCE
#  4789  356588.107248    3.972305 -1.230551 -0.003726   -0.000097     CALCE
#  4790  356618.121556    3.968579 -1.231109 -0.003726   -0.000129     CALCE
#
#        roundedV
#  0        4.101
#  1        4.088
#  2        4.079
#  3        4.071
#  4        4.065
#  ...        ...
#  4786     3.983
#  4787     3.980
#  4788     3.976
#  4789     3.972
#  4790     3.969
#
#  [4791 rows x 24 columns],
#        index  ACI_Phase_Angle(Deg)  AC_Impedance(Ohm)  Charge_Capacity(Ah)  \
#  0         2                     0                  0             0.009170
#  1         3                     0                  0             0.013755
#  2         4                     0                  0             0.018340
#  3         5                     0                  0             0.022925
#  4         6                     0                  0             0.027510
#  ...     ...                   ...                ...                  ...
#  4973   5231                     0                  0            12.648892
#  4974   5232                     0                  0            12.653476
#  4975   5233                     0                  0            12.658061
#  4976   5234                     0                  0            12.662646
#  4977   5235                     0                  0            12.667231
#
#        Charge_Energy(Wh)  Charge_dQ  Current(A)  Cycle_Index  Data_Point  \
#  0              0.032848   0.004585    0.549845            1           6
#  1              0.049547   0.004585    0.549845            1           7
#  2              0.066384   0.004585    0.549845            1           8
#  3              0.083339   0.004585    0.549845            1           9
#  4              0.100399   0.004585    0.550205            1          10
#  ...                 ...        ...         ...          ...         ...
#  4973          50.208650   0.004585    0.549845           12        5445
#  4974          50.227702   0.004585    0.549845           12        5446
#  4975          50.246769   0.004585    0.549845           12        5447
#  4976          50.265854   0.004585    0.549845           12        5448
#  4977          50.284954   0.004585    0.550025           12        5449
#
#                  Date_Time  ...  Is_FC_Data  Step_Index  Step_Time(s)  \
#  0     2010-09-27 14:15:18  ...           0           2     60.030537
#  1     2010-09-27 14:15:48  ...           0           2     90.045961
#  2     2010-09-27 14:16:18  ...           0           2    120.061120
#  3     2010-09-27 14:16:48  ...           0           2    150.076433
#  4     2010-09-27 14:17:18  ...           0           2    180.091705
#  ...                   ...  ...         ...         ...           ...
#  4973  2010-09-29 15:45:21  ...           0           2   5792.915048
#  4974  2010-09-29 15:45:51  ...           0           2   5822.930325
#  4975  2010-09-29 15:46:21  ...           0           2   5852.945581
#  4976  2010-09-29 15:46:51  ...           0           2   5882.961187
#  4977  2010-09-29 15:47:21  ...           0           2   5912.976109
#
#         Test_Time(s)  Voltage(V)     dQ/dV        dV  dV/dt(V/s)  datatype  \
#  0        180.045864    3.625319  0.113217  0.040498    0.000972     CALCE
#  1        210.061288    3.658041  0.140121  0.032722    0.000778     CALCE
#  2        240.076447    3.685742  0.165518  0.027701    0.000680     CALCE
#  3        270.091760    3.709716  0.191246  0.023975    0.000583     CALCE
#  4        300.107032    3.731099  0.214424  0.021383    0.000551     CALCE
#  ...             ...         ...       ...       ...         ...       ...
#  4973  178369.905101    4.153735  1.347755  0.003402    0.000065     CALCE
#  4974  178399.920378    4.157137  1.347565  0.003402    0.000097     CALCE
#  4975  178429.935634    4.160701  1.286620  0.003563    0.000097     CALCE
#  4976  178459.951240    4.164103  1.347592  0.003402    0.000065     CALCE
#  4977  178489.966162    4.167666  1.286630  0.003563    0.000097     CALCE
#
#        roundedV
#  0        3.625
#  1        3.658
#  2        3.686
#  3        3.710
#  4        3.731
#  ...        ...
#  4973     4.154
#  4974     4.157
#  4975     4.161
#  4976     4.164
#  4977     4.168
#
#  [4978 rows x 24 columns])
